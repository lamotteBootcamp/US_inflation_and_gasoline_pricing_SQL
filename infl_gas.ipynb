# %%
#Importing dependencies
from pprint import pprint
import pandas as pd
import json
import numpy as np

# %%
#Loading the U.S. Inflation data 
infl_raw_df = pd.read_csv('Resources/US_CPI.csv')
infl_df = infl_raw_df[['Yearmon','CPI']].rename(columns={'Yearmon':'Date',\
                                                        'CPI':'Consumer_Price_Index'})
#infl_df = infl_df.reset_index(drop=True)
infl_df.head()
#infl_df.sort_values('Date', ascending=True)
#infl_df['Date']=pd.to_datetime(infl_df['Date'], origin='unix', unit='ms').dt.date
# Out:
#          Date  Consumer_Price_Index
# 0  01-01-1913                   9.8
# 1  01-02-1913                   9.8
# 2  01-03-1913                   9.8
# 3  01-04-1913                   9.8
# 4  01-05-1913                   9.7

# %%
#Loading the U.S. Gas Price data 
gas_raw_df = pd.read_csv('Resources/PET_PRI_GND_DCUS_NUS_W.csv')
gas_df = gas_raw_df[['Date','A1','A2','A3','R1','R2','R3','M1','M2','M3','P1','P2','P3','D1',]].rename(columns={'Date':'Date',\
                                                                                                                'A1':'Weekly U.S. All Grades/Formulations Gas Prices',\
                                                                                                                'A2':'Weekly U.S. All Grades/Conventional Gas Prices',\
                                                                                                                'A3':'Weekly U.S. All Grades/Reformulated Gas Prices',\
                                                                                                               'R1':'Weekly U.S. Regular All Formulations Gas Prices',\
                                                                                                               'R2':'Weekly U.S. Regular Conventional Gas Prices',\
                                                                                                               'R3':'Weekly U.S. Regular Reformulated Gas Prices',\
                                                                                                               'M1':'Weekly U.S. Midgrade All Formulations Retail Gasoline Prices',\
                                                                                                               'M2':'Weekly U.S. Midgrade Conventional Retail Gasoline Prices',\
                                                                                                               'M3':'Weekly U.S. Midgrade Reformulated Retail Gasoline Prices',\
                                                                                                               'P1':'Weekly U.S. Premium All Formulations Retail Gasoline Prices',\
                                                                                                               'P2':'Weekly U.S. Premium Conventional Retail Gasoline Prices',\
                                                                                                               'P3':'Weekly U.S. Premium Reformulated Retail Gasoline Prices',\
                                                                                                               'D1':'Weekly U.S. No 2 Diesel Retail Prices'})
gas_df.head()
#gas_df.sort_values('Date', ascending=True)
#infl_df['Date']=pd.to_datetime(amzn_df['Date'], origin='unix', unit='ms').dt.date
# Out:
#          Date  Weekly U.S. All Grades/Formulations Gas Prices  \
# 0  01/02/1995                                           1.127
# 1  01/09/1995                                           1.134
# 2  01/16/1995                                           1.126
# 3  01/23/1995                                           1.132
# 4  01/30/1995                                           1.131
#
#    Weekly U.S. All Grades/Conventional Gas Prices  \
# 0                                           1.104
# 1                                           1.111
# 2                                           1.102
# 3                                           1.110
# 4                                           1.109
#
#    Weekly U.S. All Grades/Reformulated Gas Prices  \
# 0                                           1.231
# 1                                           1.232
# 2                                           1.231
# 3                                           1.226
# ...

# %%
#Changing the Date format for Gas dataframe
gas_df['Date'] = pd.to_datetime(gas_df["Date"])
print(gas_df)
print(gas_df.dtypes)
# Out:
#            Date  Weekly U.S. All Grades/Formulations Gas Prices  \
# 0    1995-01-02                                           1.127
# 1    1995-01-09                                           1.134
# 2    1995-01-16                                           1.126
# 3    1995-01-23                                           1.132
# 4    1995-01-30                                           1.131
# ...         ...                                             ...
# 1356 2020-12-28                                           2.330
# 1357 2021-01-04                                           2.336
# 1358 2021-01-11                                           2.403
# 1359 2021-01-18                                           2.464
# 1360 2021-01-25                                           2.478
#
#       Weekly U.S. All Grades/Conventional Gas Prices  \
# 0                                              1.104
# 1                                              1.111
# ...

# %%
#Changing the Date format for inflation dataframe
infl_df['Date'] = pd.to_datetime(infl_df["Date"])
print(infl_df)
print(infl_df.dtypes)
# Out:
#            Date  Consumer_Price_Index
# 0    1913-01-01                 9.800
# 1    1913-01-02                 9.800
# 2    1913-01-03                 9.800
# 3    1913-01-04                 9.800
# 4    1913-01-05                 9.700
# ...         ...                   ...
# 1298 2021-01-03               264.877
# 1299 2021-01-04               267.054
# 1300 2021-01-05               269.195
# 1301 2021-01-06               271.696
# 1302 2021-01-07               273.003
#
# [1303 rows x 2 columns]
# Date                    datetime64[ns]
# Consumer_Price_Index           float64
# dtype: object

# %%
#Creating first filter for inflation table, filtering for range between 2005 and 2020
first_filt_infl_df=infl_df.loc[(infl_df['Date']>='2005-01-01') & (infl_df['Date']<'2021-01-01')]
first_filt_infl_df.head()
# Out:
#            Date  Consumer_Price_Index
# 1104 2005-01-01                 190.7
# 1105 2005-01-02                 191.8
# 1106 2005-01-03                 193.3
# 1107 2005-01-04                 194.6
# 1108 2005-01-05                 194.4

# %%
#Creating first filter for gas table, filtering for range between 2005 and 2020
first_filt_gas_df=gas_df.loc[(gas_df['Date']>='2005-01-01') & (gas_df['Date']<'2021-01-01')]
first_filt_gas_df.head()
# Out:
#           Date  Weekly U.S. All Grades/Formulations Gas Prices  \
# 522 2005-01-03                                           1.824
# 523 2005-01-10                                           1.837
# 524 2005-01-17                                           1.863
# 525 2005-01-24                                           1.896
# 526 2005-01-31                                           1.953
#
#      Weekly U.S. All Grades/Conventional Gas Prices  \
# 522                                           1.788
# 523                                           1.813
# 524                                           1.843
# 525                                           1.880
# 526                                           1.936
#
#      Weekly U.S. All Grades/Reformulated Gas Prices  \
# 522                                           1.898
# 523                                           1.887
# 524                                           1.902
# 525                                           1.929
# ...

# %%
#Filtering the Inflation one to put on a weekly rate to match with the gas table (Mondays)
infl_fin_flt_df = first_filt_infl_df.loc[first_filt_infl_df['Date'].dt.weekday == 0]
infl_fin_flt_df.head()
# Out:
#            Date  Consumer_Price_Index
# 1106 2005-01-03               193.300
# 1113 2005-01-10               199.200
# 1117 2006-01-02               198.700
# 1124 2006-01-09               202.900
# 1128 2007-01-01               202.416

# %%
#Merging the two tables using the dates as an inner join.
gas_inflation_merged_df=pd.merge(infl_fin_flt_df,first_filt_gas_df,how='inner', on='Date')
gas_inflation_merged_df.head()
# Out:
#         Date  Consumer_Price_Index  \
# 0 2005-01-03               193.300
# 1 2005-01-10               199.200
# 2 2006-01-02               198.700
# 3 2006-01-09               202.900
# 4 2007-01-01               202.416
#
#    Weekly U.S. All Grades/Formulations Gas Prices  \
# 0                                           1.824
# 1                                           1.837
# 2                                           2.281
# 3                                           2.371
# 4                                           2.382
#
#    Weekly U.S. All Grades/Conventional Gas Prices  \
# 0                                           1.788
# 1                                           1.813
# 2                                           2.277
# 3                                           2.363
# 4                                           2.340
#
#    Weekly U.S. All Grades/Reformulated Gas Prices  \
# 0                                           1.898
# ...

# %%
#Droping the rows with no values, to remove the ones that do not match between gas and inflation
gas_inflation_merged__dropna_df=gas_inflation_merged_df.dropna()

gas_inflation_merged__dropna_df
# Out:
#          Date  Consumer_Price_Index  \
# 0  2005-01-03               193.300
# 1  2005-01-10               199.200
# 2  2006-01-02               198.700
# 3  2006-01-09               202.900
# 4  2007-01-01               202.416
# 5  2007-01-08               207.917
# 6  2008-01-07               219.964
# 7  2009-01-05               213.856
# 8  2009-01-12               215.949
# 9  2010-01-04               218.009
# 10 2010-01-11               218.803
# 11 2011-01-03               223.467
# 12 2011-01-10               226.421
# 13 2012-01-02               227.663
# 14 2012-01-09               231.407
# 15 2013-01-07               233.596
# 16 2014-01-06               238.343
# 17 2015-01-05               237.805
# 18 2015-01-12               236.525
# 19 2016-01-04               239.261
# 20 2016-01-11               241.353
# 21 2017-01-02               243.603
# 22 2017-01-09               246.819
# 23 2018-01-01               247.867
# 24 2018-01-08               252.146
# ...

# %%
#Creating a new column that displays only the date year, with the intention to groupby and drop later dates in that year.
gas_inflation_merged__dropna_df['Year'] = gas_inflation_merged__dropna_df['Date'].dt.year
gas_inflation_merged__dropna_df
# Out:
#          Date  Consumer_Price_Index  \
# 0  2005-01-03               193.300
# 1  2005-01-10               199.200
# 2  2006-01-02               198.700
# 3  2006-01-09               202.900
# 4  2007-01-01               202.416
# 5  2007-01-08               207.917
# 6  2008-01-07               219.964
# 7  2009-01-05               213.856
# 8  2009-01-12               215.949
# 9  2010-01-04               218.009
# 10 2010-01-11               218.803
# 11 2011-01-03               223.467
# 12 2011-01-10               226.421
# 13 2012-01-02               227.663
# 14 2012-01-09               231.407
# 15 2013-01-07               233.596
# 16 2014-01-06               238.343
# 17 2015-01-05               237.805
# 18 2015-01-12               236.525
# 19 2016-01-04               239.261
# 20 2016-01-11               241.353
# 21 2017-01-02               243.603
# 22 2017-01-09               246.819
# 23 2018-01-01               247.867
# 24 2018-01-08               252.146
# ...

# %%
#Groupby the year, and the minimum date in the 'Date' column, and generating a new dataframe to merge with the present one.
first_day = gas_inflation_merged__dropna_df.groupby('Year')['Date'].min()

# %%
first_day
# Out:
# Year
# 2005   2005-01-03
# 2006   2006-01-02
# 2007   2007-01-01
# 2008   2008-01-07
# 2009   2009-01-05
# 2010   2010-01-04
# 2011   2011-01-03
# 2012   2012-01-02
# 2013   2013-01-07
# 2014   2014-01-06
# 2015   2015-01-05
# 2016   2016-01-04
# 2017   2017-01-02
# 2018   2018-01-01
# 2019   2019-01-07
# 2020   2020-01-06
# Name: Date, dtype: datetime64[ns]

# %%
#Merging the two dataframes to remove later dates and only leave the first mondays in the respective years.
final_attempt_df=pd.merge(first_day,gas_inflation_merged_df,how='inner', on='Date')

# %%
final_attempt_df.head()
# Out:
#         Date  Consumer_Price_Index  \
# 0 2005-01-03               193.300
# 1 2006-01-02               198.700
# 2 2007-01-01               202.416
# 3 2008-01-07               219.964
# 4 2009-01-05               213.856
#
#    Weekly U.S. All Grades/Formulations Gas Prices  \
# 0                                           1.824
# 1                                           2.281
# 2                                           2.382
# 3                                           3.159
# 4                                           1.737
#
#    Weekly U.S. All Grades/Conventional Gas Prices  \
# 0                                           1.788
# 1                                           2.277
# 2                                           2.340
# 3                                           3.135
# 4                                           1.720
#
#    Weekly U.S. All Grades/Reformulated Gas Prices  \
# 0                                           1.898
# ...

# %%
#Droping null values from the dataframe
final_gas_infl_df = final_attempt_df.dropna()
final_gas_infl_df
# Out:
#          Date  Consumer_Price_Index  \
# 0  2005-01-03               193.300
# 1  2006-01-02               198.700
# 2  2007-01-01               202.416
# 3  2008-01-07               219.964
# 4  2009-01-05               213.856
# 5  2010-01-04               218.009
# 6  2011-01-03               223.467
# 7  2012-01-02               227.663
# 8  2013-01-07               233.596
# 9  2014-01-06               238.343
# 10 2015-01-05               237.805
# 11 2016-01-04               239.261
# 12 2017-01-02               243.603
# 13 2018-01-01               247.867
# 14 2019-01-07               256.571
# 15 2020-01-06               257.797
#
#     Weekly U.S. All Grades/Formulations Gas Prices  \
# 0                                            1.824
# 1                                            2.281
# 2                                            2.382
# 3                                            3.159
# 4                                            1.737
# ...

# %%
#Generating new column to display percentage change to Consumer Price Index column
final_gas_infl_df['CPI Change']=final_gas_infl_df['Consumer_Price_Index'].pct_change(periods=1)
final_gas_infl_df['CPI Change']
# Out:
# 0          NaN
# 1     0.027936
# 2     0.018702
# 3     0.086693
# 4    -0.027768
# 5     0.019420
# 6     0.025036
# 7     0.018777
# 8     0.026060
# 9     0.020321
# 10   -0.002257
# 11    0.006123
# 12    0.018148
# 13    0.017504
# 14    0.035116
# 15    0.004778
# Name: CPI Change, dtype: float64

# %%
#Setting Date as index
final_gas_infl_df.set_index("Date")
# Out:
#             Consumer_Price_Index  \
# Date
# 2005-01-03               193.300
# 2006-01-02               198.700
# 2007-01-01               202.416
# 2008-01-07               219.964
# 2009-01-05               213.856
# 2010-01-04               218.009
# 2011-01-03               223.467
# 2012-01-02               227.663
# 2013-01-07               233.596
# 2014-01-06               238.343
# 2015-01-05               237.805
# 2016-01-04               239.261
# 2017-01-02               243.603
# 2018-01-01               247.867
# 2019-01-07               256.571
# 2020-01-06               257.797
#
#             Weekly U.S. All Grades/Formulations Gas Prices  \
# Date
# 2005-01-03                                           1.824
# 2006-01-02                                           2.281
# 2007-01-01                                           2.382
# 2008-01-07                                           3.159
# 2009-01-05                                           1.737
# ...

# %%
#New column to display percentage change to average of all grades gas prices
final_gas_infl_df['All Grades/Formulations Percent Change']=final_gas_infl_df['Weekly U.S. All Grades/Formulations Gas Prices'].pct_change(periods=1)
final_gas_infl_df['All Grades/Formulations Percent Change']
# Out:
# 0          NaN
# 1     0.250548
# 2     0.044279
# 3     0.326196
# 4    -0.450142
# 5     0.564767
# 6     0.149375
# 7     0.074904
# 8     0.004467
# 9     0.011266
# 10   -0.323366
# 11   -0.074957
# 12    0.163934
# 13    0.061167
# 14   -0.116799
# 15    0.144268
# Name: All Grades/Formulations Percent Change, dtype: float64

# %%
final_gas_infl_df['All Grades/Conventional Percent Change']=final_gas_infl_df['Weekly U.S. All Grades/Conventional Gas Prices'].pct_change(periods=1)
final_gas_infl_df['All Grades/Conventional Percent Change']
# Out:
# 0          NaN
# 1     0.273490
# 2     0.027668
# 3     0.339744
# 4    -0.451356
# 5     0.556395
# 6     0.152783
# 7     0.072586
# 8    -0.001813
# 9     0.010896
# 10   -0.332934
# 11   -0.090215
# 12    0.198323
# 13    0.051462
# 14   -0.138998
# 15    0.164620
# Name: All Grades/Conventional Percent Change, dtype: float64

# %%
final_gas_infl_df['All Grades/Reformulated Percent Change']=final_gas_infl_df['Weekly U.S. All Grades/Reformulated Gas Prices'].pct_change(periods=1)
final_gas_infl_df['All Grades/Reformulated Percent Change']
# Out:
# 0          NaN
# 1     0.206533
# 2     0.076419
# 3     0.301420
# 4    -0.447631
# 5     0.581264
# 6     0.142398
# 7     0.079038
# 8     0.016792
# 9     0.012813
# 10   -0.305032
# 11   -0.047735
# 12    0.104928
# 13    0.078047
# 14   -0.080599
# 15    0.113266
# Name: All Grades/Reformulated Percent Change, dtype: float64

# %%
final_gas_infl_df['Regular All Formulations Percent Change']=final_gas_infl_df['Weekly U.S. Regular All Formulations Gas Prices'].pct_change(periods=1)
final_gas_infl_df['Regular All Formulations Percent Change']
# Out:
# 0          NaN
# 1     0.258718
# 2     0.042895
# 3     0.332048
# 4    -0.458347
# 5     0.582542
# 6     0.151970
# 7     0.074593
# 8     0.000000
# 9     0.010003
# 10   -0.335534
# 11   -0.084011
# 12    0.172091
# 13    0.060160
# 14   -0.112302
# 15    0.152436
# Name: Regular All Formulations Percent Change, dtype: float64

# %%
#final_gas_infl_df['Regular/conventional Change']=final_gas_infl_df['Weekly U.S. Regular Conventional Gas Prices'].pct_change(periods=1)
#final_gas_infl_df['Regular/conventional Change']

# %%
#final_gas_infl_df['Regular/Reformulated Change']=final_gas_infl_df['Weekly U.S. Regular Reformulated Gas Prices'].pct_change(periods=1)
#final_gas_infl_df['Regular/Reformulated Change']

# %%
#final_gas_infl_df['Midgrade/All Formulations Change']=final_gas_infl_df['Weekly U.S. Midgrade All Formulations Retail Gasoline Prices'].pct_change(periods=1)
#final_gas_infl_df['Midgrade/All Formulations Change']

# %%
#final_gas_infl_df['Midgrade/Conventional Change']=final_gas_infl_df['Weekly U.S. Midgrade Conventional Retail Gasoline Prices'].pct_change(periods=1)
#final_gas_infl_df['Midgrade/Conventional Change']

# %%
#final_gas_infl_df['Midgrade/Reformulated Change']=final_gas_infl_df['Weekly U.S. Midgrade Reformulated Retail Gasoline Prices'].pct_change(periods=1)
#final_gas_infl_df['Midgrade/Reformulated Change']

# %%
#final_gas_infl_df['Premium/All Formulations Change']=final_gas_infl_df['Weekly U.S. Premium All Formulations Retail Gasoline Prices'].pct_change(periods=1)
#final_gas_infl_df['Premium/All Formulations Change']

# %%
#final_gas_infl_df['Premium/Conventional Retail Change']=final_gas_infl_df['Weekly U.S. Premium Conventional Retail Gasoline Prices'].pct_change(periods=1)
#final_gas_infl_df['Premium/Conventional Retail Change']

# %%
#final_gas_infl_df['Premium/Reformulated Change']=final_gas_infl_df['Weekly U.S. Premium Reformulated Retail Gasoline Prices'].pct_change(periods=1)
#final_gas_infl_df['Premium/Reformulated Change']

# %%
#final_gas_infl_df['No 2 Diesel Change']=final_gas_infl_df['Weekly U.S. No 2 Diesel Retail Prices'].pct_change(periods=1)
#final_gas_infl_df['No 2 Diesel Change']

# %%
final_gas_infl_df.head()
# Out:
#         Date  Consumer_Price_Index  \
# 0 2005-01-03               193.300
# 1 2006-01-02               198.700
# 2 2007-01-01               202.416
# 3 2008-01-07               219.964
# 4 2009-01-05               213.856
#
#    Weekly U.S. All Grades/Formulations Gas Prices  \
# 0                                           1.824
# 1                                           2.281
# 2                                           2.382
# 3                                           3.159
# 4                                           1.737
#
#    Weekly U.S. All Grades/Conventional Gas Prices  \
# 0                                           1.788
# 1                                           2.277
# 2                                           2.340
# 3                                           3.135
# 4                                           1.720
#
#    Weekly U.S. All Grades/Reformulated Gas Prices  \
# 0                                           1.898
# ...

# %%
#Exporting final dataframe to csv file.
final_gas_infl_df.to_csv(r'cleaning_results\gas_cpi.csv',index=False)
